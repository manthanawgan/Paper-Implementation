# %% [markdown]
# <a href="https://colab.research.google.com/github/manthanawgan/Paper-Implementation/blob/main/Transformer(attention_ppr).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Implementation Roadmap
# - **Embeddings & Positional Encoding**: Create a module that adds sine/cosine waves to your input token embeddings.
#
# - **The "Add & Norm" Wrapper**: Create a helper that takes a sublayer (like Attention), applies it, adds the residual connection, and then calls nn.LayerNorm.
#
# - **The Encoder Layer**: Combine Multi-Head Attention and the Feed-Forward network using your "Add & Norm" wrapper.
#
# - **The Encoder Stack**: Use nn.ModuleList to stack 6 identical Encoder Layers.
#
# - **The Decoder**: Repeat the process, but remember the Decoder Layer has two attention blocks (Self-Attention and Encoder-Decoder Attention).

# %%
import torch

torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# ## Scaled - Dot Product Attenetion

# %%
import torch.nn as nn

# %% [markdown]
# ## Multi-Head Attention

# %% [markdown]
# ## Position-Wise feed forward network

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from tokenizers import Tokenizer
from torch.utils.data import Dataset, DataLoader

# %%
class InputEmbedding:
  def __init__(self, d_model = int, vocab_size = int) -> None:
    super().__init__()
      self.d_model = d_model
      self.vocab_size = vocab_size
      self.embedding = nn.Embedding(vocab_size, d_model)


  def forward( self, x):
    return self.embedding(x) * math.sqrt(self.d_model)
